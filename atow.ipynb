# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt1
import scipy.signal

from scipy.io import wavfile as wav
rate, data = wav.read('harry.wav')
rate, data1 = wav.read('harry.wav')

# %matplotlib inline

plt.plot(data)
plt.show()
plt1.plot(data1)
plt1.show()
# Out:
# True
